# %%
# testbook
# for testing textbook stuff
# Michael Song, songmichael11@gmail.com

# For plotting
import matplotlib
import matplotlib.pyplot as plt

# For data formatting
import numpy as np
import pandas as pd
import random

# SMILES processing
from rdkit.Chem import AllChem

# For models
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape

# %%
pca = PCA(2) # project from 64 to 2 dimensions
projected = pca.fit_transform(X_test.data)
print(X_test.data.shape)
print(projected.shape)
plt.scatter(projected[:, 0], projected[:, 1],
c=Y_test, edgecolor='none', alpha=0.5,
cmap=plt.cm.get_cmap('Spectral'))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar()
# Out:
# (329, 1024)
# (329, 2)
# /var/folders/hh/fvxmgxxd3x5fqqm0w3fmy1d80000gn/T/ipykernel_60986/3519556063.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap('Spectral'))
